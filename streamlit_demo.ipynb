# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 946 kB/s eta 0:00:01
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 19.6 MB/s eta 0:00:01
# Collecting numpy<3,>=1.23
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 31.2 MB/s eta 0:00:01
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 24.9 MB/s eta 0:00:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/lehanzhao/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.5)
# Collecting altair<6,>=4.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#      |████████████████████████████████| 731 kB 27.2 MB/s eta 0:00:01
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 28.5 MB/s eta 0:00:01
# Collecting pandas<3,>=1.4.0
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 31.4 MB/s eta 0:00:01
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/lehanzhao/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.13.2)
# Collecting protobuf<7,>=3.20
#   Downloading protobuf-6.31.0-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
#      |████████████████████████████████| 425 kB 23.4 MB/s eta 0:00:01
# Collecting requests<3,>=2.27
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 9.7 MB/s  eta 0:00:01
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting blinker<2,>=1.5.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting pillow<12,>=7.1.0
#   Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 31.6 MB/s eta 0:00:01
# Collecting pyarrow>=7.0
#   Downloading pyarrow-20.0.0-cp39-cp39-macosx_12_0_arm64.whl (30.8 MB)
#      |████████████████████████████████| 30.8 MB 27.3 MB/s eta 0:00:01
# Collecting packaging<25,>=20
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 15.2 MB/s eta 0:00:01
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 17.4 MB/s eta 0:00:01
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 16.3 MB/s eta 0:00:01
# Collecting narwhals>=1.14.2
#   Downloading narwhals-1.40.0-py3-none-any.whl (357 kB)
#      |████████████████████████████████| 357 kB 20.1 MB/s eta 0:00:01
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 5.6 MB/s  eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.25.0-cp39-cp39-macosx_11_0_arm64.whl (359 kB)
#      |████████████████████████████████| 359 kB 26.0 MB/s eta 0:00:01
# Collecting attrs>=22.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 9.5 MB/s  eta 0:00:01
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 33.7 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 26.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/lehanzhao/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.15.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 25.0 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp39-cp39-macosx_10_9_universal2.whl (201 kB)
#      |████████████████████████████████| 201 kB 30.0 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 16.4 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 31.1 MB/s eta 0:00:01
# Installing collected packages: rpds-py, attrs, referencing, smmap, MarkupSafe, jsonschema-specifications, urllib3, tzdata, pytz, packaging, numpy, narwhals, jsonschema, jinja2, idna, gitdb, charset-normalizer, certifi, toml, tenacity, requests, pydeck, pyarrow, protobuf, pillow, pandas, gitpython, click, cachetools, blinker, altair, streamlit
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed MarkupSafe-3.0.2 altair-5.5.0 attrs-25.3.0 blinker-1.9.0 cachetools-5.5.2 certifi-2025.4.26 charset-normalizer-3.4.2 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 idna-3.10 jinja2-3.1.6 jsonschema-4.23.0 jsonschema-specifications-2025.4.1 narwhals-1.40.0 numpy-2.0.2 packaging-24.2 pandas-2.2.3 pillow-11.2.1 protobuf-6.31.0 pyarrow-20.0.0 pydeck-0.9.1 pytz-2025.2 referencing-0.36.2 requests-2.32.3 rpds-py-0.25.0 smmap-5.0.2 streamlit-1.45.1 tenacity-9.1.2 toml-0.10.2 tzdata-2025.2 urllib3-2.4.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# Set page configuration
st.set_page_config(
    page_title="Photo Upload Demo",
    layout="wide"
)

# Add a title
st.title("Photo Upload Application")

# Create two columns for the upload blocks
col1, col2 = st.columns(2)

# First upload block
with col1:
    st.header("First Photo Upload")
    st.write("Upload your first photo here")
    photo1 = st.file_uploader(
        "Choose your first photo",
        type=["jpg", "jpeg", "png"],
        key="uploader1"
    )
    
    if photo1 is not None:
        st.image(photo1, caption="First uploaded photo", use_column_width=True)
        st.write(f"Filename: {photo1.name}")
        st.write(f"File size: {photo1.size} bytes")

# Second upload block
with col2:
    st.header("Second Photo Upload")
    st.write("Upload your second photo here")
    photo2 = st.file_uploader(
        "Choose your second photo",
        type=["jpg", "jpeg", "png"],
        key="uploader2"
    )
    
    if photo2 is not None:
        st.image(photo2, caption="Second uploaded photo", use_column_width=True)
        st.write(f"Filename: {photo2.name}")
        st.write(f"File size: {photo2.size} bytes")
# Out:
# 2025-05-20 17:22:26.559 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.559 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.596
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/lehanzhao/Library/Python/3.9/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-05-20 17:22:26.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-20 17:22:26.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
